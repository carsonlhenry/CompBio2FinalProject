# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(img,cmap='gray'):
    fig= plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
crunch= cv2.imread("crunch.jpg")
display(crunch)

# %%
all_cereal= cv2.imread("all cereal.jpg")
display(all_cereal)

# %%
orb = cv2.ORB_create()

kp1,des1= orb.detectAndCompute(crunch, mask=None)
kp2,des2= orb.detectAndCompute (cereal, mask=None)

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
matches= bf.match(des1,des2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-31-f32d2e4f24bb> in <module>
#       1 bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
# ----> 2 matches= bf.match(des1,des2)
#
# error: OpenCV(4.9.0) /io/opencv/modules/core/src/batch_distance.cpp:274: error: (-215:Assertion failed) type == src2.type() && src1.cols == src2.cols && (type == CV_32F || type == CV_8U) in function 'batchDistance'

# %%
matches = sorted(matches, key = lambda x:x.distance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-eba1117919a5> in <module>
# ----> 1 matches = sorted(matches, key = lambda x:x.distance)
#
# NameError: name 'matches' is not defined
