# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("Tulip.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# Dwnld wrong
img_wrong = cv2.imread("wrong/path/notexist")

# %%
type (img_wrong)
# wrong image type
# Out:
# NoneType

# %%
plt.imshow(img)

# %%
# We can fix the color of the image to exactly like the internet

fix_img = cv2.cvtColor (img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("Tulip.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap ="gray")

# %%
# Resize

fix_img.shape
# Out:
# (768, 1024, 3)

# %%
new_img=cv2.resize(fix_img,(1000,400))
plt.imshow(new_img)

# %%
w_ratio= 0.5
h_ratio= 0.5

new_img= cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (384, 512, 3)

# %%
flip_img = cv2.flip(fix_img,0)
plt.imshow(flip_img)

# %%
flip_img2 = cv2.flip(fix_img,-1)
plt.imshow(flip_img2)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('Tulip_fixed_image.jpg', fix_img)
# Out:
# True
