# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("Tulip.jpg")

# %%
plt.imshow(img)

# %%
img1 = cv2.cvtColor (img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
# Hue Saturation Value
img2 = cv2.cvtColor (img, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img2)

# %%
img3 = cv2.cvtColor (img, cv2.COLOR_BGR2HLS)

# %%
plt.imshow(img3)

# %%
img1= cv2.imread("Sign.jpg")
img2= cv2.imread("Tuplip.jpg")

# %%
plt.imshow(img1)

# %%
img1= cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
img1 = cv2.resize (img1,(1200,1200))
img2 = cv2.resize (img2,(1200,1200))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-79-585ccdedfee4> in <module>
#       1 img1 = cv2.resize (img1,(1200,1200))
# ----> 2 img2 = cv2.resize (img2,(1200,1200))
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgproc/src/resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
alpha =0.5
beta =0.5

# %%
blended = cv2.addWeighted(img1, alpha, img2, beta, gamma=0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-64-fbcc42a1e8a2> in <module>
# ----> 1 blended = cv2.addWeighted(img1, alpha, img2, beta, gamma=0)
#
# error: OpenCV(4.9.0) /io/opencv/modules/core/src/arithm.cpp:647: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-e9b711fed305> in <module>
# ----> 1 plt.imshow(blended)
#
# NameError: name 'blended' is not defined
